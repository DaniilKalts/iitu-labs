# %% [markdown]
# # Laboratory Work #1

# %% [markdown]
# ## Group: IT2-2404SE
# ## Full Name: Daniil Kalts

# %% [markdown]
# ### Exercise 1
# Any fraction can be written as the division of two integers. You could express this in Python as a tuple – (numerator, denominator). Write functions for each of the following. They must use the tuple representation to return fractions.
#
# 1. Given two fractions as tuples, multiply them.
# 2. Given two fractions as tuples, divide them.
# 3. Given a list of fractions as a tuple, return the one that is smallest in value. Also write a small command-line interface such that the user running your script sees something like this:

# %%
# def multiply_fractions(fraction_1, fraction_2):
#     out = [val_1 * val_2 for val_1, val_2 in zip(listed_fraction_1, listed_fraction_2)]
#     return tuple(out)

# def divide_fractions(fraction_1, fraction_2):
#     out = [val_1 / val_2 for val_1, val_2 in zip(listed_fraction_1, listed_fraction_2)]
#     return tuple(out)

# fraction_1 = input('Enter a fraction >>> ')
# fraction_2 = input('Enter a fraction >>> ')

# listed_fraction_1 = fraction_1.split('/')
# listed_fraction_1 = [int(part) for part in listed_fraction_1]

# listed_fraction_2 = fraction_2.split('/')
# listed_fraction_2 = [int(part) for part in listed_fraction_2]

# multiply_fractions_out = multiply_fractions(tuple(listed_fraction_1), tuple(listed_fraction_2))
# divide_fractions_out = divide_fractions(tuple(listed_fraction_1), tuple(listed_fraction_2))

# print('== Multiplication and Division ==')
# print('Multiplication of the fractions:', multiply_fractions_out)
# print('Division of the first by the second:', divide_fractions_out)

print('== Smallest fraction ==')
fractions = []

while True:
    val = input('Enter a fraction >>> ')
    
    if val == 'stop':
        break

    # В перспективе можно добавить валидатор для фракции,
    # но давайте верить в добросовестность пользователя,
    # который будет вводить фракции :D
    fractions.append(val)

print(fractions)
# Out:
# == Smallest fraction ==
# Enter a fraction >>>  1/3
# Enter a fraction >>>  2/3
# Enter a fraction >>>  4/5
# Enter a fraction >>>  stop
# ['1/3', '2/3', '4/5']
